# %% [markdown]
# # Slovene preprocessing, rule-based systems, regular expressions
#
# <sup>This notebook is a part of Natural Language Processing class at the University of Ljubljana, Faculty for computer and information science. Please contact [slavko.zitnik@fri.uni-lj.si](mailto:slavko.zitnik@fri.uni-lj.si) for any comments.</sub>
#
# ## Slovene text preprocessing
#
# Most of the tools and corpora is available at [ssj.slovenscina.eu](http://ssj.slovenscina.eu/) or [clarin.si](http://www.clarin.si/info/o-projektu/). Some direct links to the available tools are:
#
# * [Part-of-speech tagger](http://oznacevalnik.slovenscina.eu/Vsebine/Sl/ProgramskaOprema/Navodila.aspx): The  tool includes part-of-speech pagger, tokenizer and lemmatizer Lemmagen. Part-of-speech annotation examples are described at [http://bos.zrc-sazu.si/bibliografija/o_oznake.html](http://bos.zrc-sazu.si/bibliografija/o_oznake.html), [http://nl.ijs.si/imp/msd/html-sl/](http://nl.ijs.si/imp/msd/html-sl/) or [https://www.jakopin.net/primoz/disertacija/oblikozn.php](https://www.jakopin.net/primoz/disertacija/oblikozn.php).
# * [Dependency parser](http://razclenjevalnik.slovenscina.eu/Default.aspx) - Labels explanation ["Površinskoskladenjsko označevanje korpusa Slovene Dependency Treebank," bachelor thesis by Nina Ledinek](https://nl.ijs.si/sdt/bib/SDT-diploma-nina.pdf).
# * [Lemmatizer Lemmagen](http://lemmatise.ijs.si/Software/): A port to Java also exists - [Lemmagen4J](https://github.com/szitnik/Lemmagen4J)
# * Currently best lemmatizer, tokenizer, part-of-speech tagger (year 2022) - Stanza is based on Stanford's model and available at [clarin repository](https://www.clarin.si/repository/xmlui/handle/11356/1412) and regulary updated in the [Stanza's Github repo](https://github.com/clarinsi/classla).
# * [SloBENCH](https://slobench.cjvt.si/): Slovenian NLP tools benchmark.
# * Project RSDO (2020-2023) results: [slovenscina.eu](http://slovenscina.eu/).
#
# Project PoVeJMo is currently on-going (2023-2026).
#
# There already exist some pre-trained deep neural network model we will discuss later.

# %%
import classla
# download standard models for Slovenian
classla.download('sl')
# Out:
# Downloading https://raw.githubusercontent.com/clarinsi/classla-resources/main/resources_2.1.json: 11.4kB [00:00, 23.8MB/s]
# 2024-02-27 03:20:24 INFO: Downloading these customized packages for language: sl (Slovenian)...
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | standard |
# | pos       | standard |
# | lemma     | standard |
# | depparse  | standard |
# | ner       | standard |
# | pretrain  | standard |
# ========================
#
# 2024-02-27 03:20:26 INFO: File exists: /Users/slavkoz/classla_resources/sl/pos/standard.pt.
# 2024-02-27 03:20:26 INFO: File exists: /Users/slavkoz/classla_resources/sl/lemma/standard.pt.
# 2024-02-27 03:20:26 INFO: File exists: /Users/slavkoz/classla_resources/sl/depparse/standard.pt.
# 2024-02-27 03:20:26 INFO: File exists: /Users/slavkoz/classla_resources/sl/ner/standard.pt.
# 2024-02-27 03:20:27 INFO: File exists: /Users/slavkoz/classla_resources/sl/pretrain/standard.pt.
# 2024-02-27 03:20:27 INFO: Finished downloading models and saved to /Users/slavkoz/classla_resources.

# %%
# RTV SLO article, March 7, 2022
text = """
V Belorusiji se je začel tretji krog pogajanj o premirju. 
Na mizi so zahteve o notranjepolitični rešitvi krize, mednarodno 
humanitarnem in vojaškem vidiku. Ruska vojska je že zjutraj odprla 
humanitarne koridorje, a jih večina vodi v Rusijo in Belorusijo.

Tretji krog mirovnih pogajanj poteka v narodnem parku Beloveška 
pušča, ki se razteza med Poljsko in Belorusijo. Ruske pogajalce 
vodi Vladimir Medinski, ki je dejal, da je Rusija 
"nedvomno pripravljena" na pogovore z ukrajinsko stranjo, poroča 
ruska tiskovna agencija TASS.
"""

# %%
nlp = classla.Pipeline('sl', processors='tokenize,ner,pos,lemma,depparse')                      
doc = nlp(text)     
doc
# Out:
# 2024-02-27 03:20:27 INFO: Loading these models for language: sl (Slovenian):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | standard |
# | pos       | standard |
# | lemma     | standard |
# | depparse  | standard |
# | ner       | standard |
# ========================
#
# 2024-02-27 03:20:27 INFO: Use device: cpu
# 2024-02-27 03:20:27 INFO: Loading: tokenize
# 2024-02-27 03:20:27 INFO: Loading: pos
# 2024-02-27 03:20:36 INFO: Loading: lemma
# 2024-02-27 03:20:48 INFO: Loading: depparse
# 2024-02-27 03:20:48 INFO: Loading: ner
# 2024-02-27 03:20:48 INFO: Done loading processors!
# [
#   [
#     [
#       {
#         "id": 1,
#         "text": "V",
#         "lemma": "v",
#         "upos": "ADP",
#         "xpos": "Sl",
#         "feats": "Case=Loc",
#         "head": 2,
#         "deprel": "case",
#         "ner": "O"
#       },
#       {
#         "id": 2,
#         "text": "Belorusiji",
#         "lemma": "Belorusija",
#         "upos": "PROPN",
#         "xpos": "Npfsl",
#         "feats": "Case=Loc|Gender=Fem|Number=Sing",
#         "head": 5,
#         "deprel": "obl",
#         "ner": "B-LOC"
#       },
#       {
#         "id": 3,
#         "text": "se",
#         "lemma": "se",
#         "upos": "PRON",
#         "xpos": "Px------y",
#         "feats": "PronType=Prs|Reflex=Yes|Variant=Short",
#         "head": 5,
#         "deprel": "expl",
#         "ner": "O"
#       },
#       {
#         "id": 4,
#         "text": "je",
#         "lemma": "biti",
#         "upos": "AUX",
#         "xpos": "Va-r3s-n",
#         "feats": "Mood=Ind|Number=Sing|Person=3|Polarity=Pos|Tense=Pres|VerbForm=Fin",
#         "head": 5,
#         "deprel": "aux",
#         "ner": "O"
#       },
#       {
#         "id": 5,
#         "text": "začel",
#         "lemma": "začeti",
#         "upos": "VERB",
#         "xpos": "Vmep-sm",
#         "feats": "Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part",
#         "head": 0,
#         "deprel": "root",
#         "ner": "O"
#       },
#       {
#         "id": 6,
#         "text": "tretji",
#         "lemma": "tretji",
#         "upos": "ADJ",
#         "xpos": "Mlomsn",
#         "feats": "Case=Nom|Gender=Masc|Number=Sing|NumType=Ord",
#         "head": 7,
#         "deprel": "amod",
#         "ner": "O"
#       },
#       {
#         "id": 7,
#         "text": "krog",
#         "lemma": "krog",
#         "upos": "NOUN",
#         "xpos": "Ncmsn",
#         "feats": "Case=Nom|Gender=Masc|Number=Sing",
#         "head": 5,
#         "deprel": "nsubj",
#         "ner": "O"
#       },
#       {
#         "id": 8,
#         "text": "pogajanj",
#         "lemma": "pogajanje",
#         "upos": "NOUN",
#         "xpos": "Ncnpg",
#         "feats": "Case=Gen|Gender=Neut|Number=Plur",
#         "head": 7,
#         "deprel": "nmod",
#         "ner": "O"
#       },
#       {
#         "id": 9,
#         "text": "o",
#         "lemma": "o",
#         "upos": "ADP",
#         "xpos": "Sl",
#         "feats": "Case=Loc",
#         "head": 10,
#         "deprel": "case",
#         "ner": "O"
#       },
#       {
#         "id": 10,
#         "text": "premirju",
#         "lemma": "premirje",
#         "upos": "NOUN",
#         "xpos": "Ncnsl",
#         "feats": "Case=Loc|Gender=Neut|Number=Sing",
#         "head": 8,
#         "deprel": "nmod",
#         "misc": "SpaceAfter=No",
#         "ner": "O"
#       },
#       {
#         "id": 11,
#         "text": ".",
#         "lemma": ".",
#         "upos": "PUNCT",
#         "xpos": "Z",
#         "head": 5,
#         "deprel": "punct",
#         "ner": "O"
#       }
#     ],
#     "# newpar id = 1\n# sent_id = 1.1\n# text = V Belorusiji se je začel tretji krog pogajanj o premirju.\n"
#   ],
#   [
#     [
#       {
#         "id": 1,
#         "text": "Na",
#         "lemma": "na",
#         "upos": "ADP",
#         "xpos": "Sl",
#         "feats": "Case=Loc",
#         "head": 2,
#         "deprel": "case",
#         "ner": "O"
#       },
#       {
#         "id": 2,
#         "text": "mizi",
#         "lemma": "miza",
#         "upos": "NOUN",
#         "xpos": "Ncfsl",
#         "feats": "Case=Loc|Gender=Fem|Number=Sing",
#         "head": 4,
#         "deprel": "obl",
#         "ner": "O"
#       },
#       {
#         "id": 3,
#         "text": "so",
#         "lemma": "biti",
#         "upos": "AUX",
#         "xpos": "Va-r3p-n",
#         "feats": "Mood=Ind|Number=Plur|Person=3|Polarity=Pos|Tense=Pres|VerbForm=Fin",
#         "head": 4,
#         "deprel": "cop",
#         "ner": "O"
#       },
#       {
#         "id": 4,
#         "text": "zahteve",
#         "lemma": "zahteva",
#         "upos": "NOUN",
#         "xpos": "Ncfpn",
#         "feats": "Case=Nom|Gender=Fem|Number=Plur",
#         "head": 0,
#         "deprel": "root",
#         "ner": "O"
#       },
#       {
#         "id": 5,
#         "text": "o",
#         "lemma": "o",
#         "upos": "ADP",
#         "xpos": "Sl",
#         "feats": "Case=Loc",
#         "head": 7,
#         "deprel": "case",
#         "ner": "O"
#       },
#       {
#         "id": 6,
#         "text": "notranjepolitični",
#         "lemma": "notranjepolitičen",
#         "upos": "ADJ",
#         "xpos": "Agpfsl",
#         "feats": "Case=Loc|Degree=Pos|Gender=Fem|Number=Sing",
#         "head": 7,
#         "deprel": "amod",
#         "ner": "O"
#       },
#       {
#         "id": 7,
#         "text": "rešitvi",
#         "lemma": "rešitev",
#         "upos": "NOUN",
#         "xpos": "Ncfsl",
#         "feats": "Case=Loc|Gender=Fem|Number=Sing",
#         "head": 4,
#         "deprel": "nmod",
#         "ner": "O"
#       },
#       {
#         "id": 8,
#         "text": "krize",
#         "lemma": "kriza",
#         "upos": "NOUN",
#         "xpos": "Ncfsg",
#         "feats": "Case=Gen|Gender=Fem|Number=Sing",
#         "head": 7,
#         "deprel": "nmod",
#         "misc": "SpaceAfter=No",
#         "ner": "O"
#       },
#       {
#         "id": 9,
#         "text": ",",
#         "lemma": ",",
#         "upos": "PUNCT",
#         "xpos": "Z",
#         "head": 10,
#         "deprel": "punct",
#         "ner": "O"
#       },
#       {
#         "id": 10,
#         "text": "mednarodno",
#         "lemma": "mednarodno",
#         "upos": "ADV",
#         "xpos": "Rgp",
#         "feats": "Degree=Pos",
#         "head": 4,
#         "deprel": "discourse",
#         "ner": "O"
#       }
#     ],
#     "# newpar id = 2\n# sent_id = 2.1\n# text = Na mizi so zahteve o notranjepolitični rešitvi krize, mednarodno\n"
#   ],
#   [
#     [
#       {
#         "id": 1,
#         "text": "humanitarnem",
#         "lemma": "humanitaren",
#         "upos": "ADJ",
#         "xpos": "Agpmsd",
#         "feats": "Case=Dat|Degree=Pos|Gender=Masc|Number=Sing",
#         "head": 4,
#         "deprel": "amod",
#         "ner": "O"
#       },
#       {
#         "id": 2,
#         "text": "in",
#         "lemma": "in",
#         "upos": "CCONJ",
#         "xpos": "Cc",
#         "head": 3,
#         "deprel": "cc",
#         "ner": "O"
#       },
#       {
#         "id": 3,
#         "text": "vojaškem",
#         "lemma": "vojaški",
#         "upos": "ADJ",
#         "xpos": "Agpmsl",
#         "feats": "Case=Loc|Degree=Pos|Gender=Masc|Number=Sing",
#         "head": 1,
#         "deprel": "conj",
#         "ner": "O"
#       },
#       {
#         "id": 4,
#         "text": "vidiku",
#         "lemma": "vidik",
#         "upos": "NOUN",
#         "xpos": "Ncmsl",
#         "feats": "Case=Dat|Gender=Masc|Number=Sing",
#         "head": 0,
#         "deprel": "root",
#         "misc": "SpaceAfter=No",
#         "ner": "O"
#       },
#       {
#         "id": 5,
#         "text": ".",
#         "lemma": ".",
#         "upos": "PUNCT",
#         "xpos": "Z",
#         "head": 4,
#         "deprel": "punct",
#         "ner": "O"
#       }
#     ],
#     "# newpar id = 3\n# sent_id = 3.1\n# text = humanitarnem in vojaškem vidiku.\n"
#   ],
#   [
#     [
#       {
#         "id": 1,
#         "text": "Ruska",
#         "lemma": "ruski",
#         "upos": "ADJ",
#         "xpos": "Agpfsn",
#         "feats": "Case=Nom|Degree=Pos|Gender=Fem|Number=Sing",
#         "head": 2,
#         "deprel": "amod",
#         "ner": "O"
#       },
#       {
#         "id": 2,
#         "text": "vojska",
#         "lemma": "vojska",
#         "upos": "NOUN",
#         "xpos": "Ncfsn",
#         "feats": "Case=Nom|Gender=Fem|Number=Sing",
#         "head": 6,
#         "deprel": "nsubj",
#         "ner": "O"
#       },
#       {
#         "id": 3,
#         "text": "je",
#         "lemma": "biti",
#         "upos": "AUX",
#         "xpos": "Va-r3s-n",
#         "feats": "Mood=Ind|Number=Sing|Person=3|Polarity=Pos|Tense=Pres|VerbForm=Fin",
#         "head": 6,
#         "deprel": "aux",
#         "ner": "O"
#       },
#       {
#         "id": 4,
#         "text": "že",
#         "lemma": "že",
#         "upos": "PART",
#         "xpos": "Q",
#         "head": 6,
#         "deprel": "advmod",
#         "ner": "O"
#       },
#       {
#         "id": 5,
#         "text": "zjutraj",
#         "lemma": "zjutraj",
#         "upos": "ADV",
#         "xpos": "Rgp",
#         "feats": "Degree=Pos",
#         "head": 6,
#         "deprel": "advmod",
#         "ner": "O"
#       },
#       {
#         "id": 6,
#         "text": "odprla",
#         "lemma": "odpreti",
#         "upos": "VERB",
#         "xpos": "Vmep-sf",
#         "feats": "Aspect=Perf|Gender=Fem|Number=Sing|VerbForm=Part",
#         "head": 0,
#         "deprel": "root",
#         "ner": "O"
#       }
#     ],
#     "# sent_id = 3.2\n# text = Ruska vojska je že zjutraj odprla\n"
#   ],
#   [
#     [
#       {
#         "id": 1,
#         "text": "humanitarne",
#         "lemma": "humanitaren",
#         "upos": "ADJ",
#         "xpos": "Agpmpa",
#         "feats": "Case=Acc|Degree=Pos|Gender=Masc|Number=Plur",
#         "head": 2,
#         "deprel": "amod",
#         "ner": "O"
#       },
#       {
#         "id": 2,
#         "text": "koridorje",
#         "lemma": "koridor",
#         "upos": "NOUN",
#         "xpos": "Ncmpa",
#         "feats": "Case=Acc|Gender=Masc|Number=Plur",
#         "head": 0,
#         "deprel": "root",
#         "misc": "SpaceAfter=No",
#         "ner": "O"
#       },
#       {
#         "id": 3,
#         "text": ",",
#         "lemma": ",",
#         "upos": "PUNCT",
#         "xpos": "Z",
#         "head": 7,
#         "deprel": "punct",
#         "ner": "O"
#       },
#       {
#         "id": 4,
#         "text": "a",
#         "lemma": "a",
#         "upos": "CCONJ",
#         "xpos": "Cc",
#         "head": 7,
#         "deprel": "cc",
#         "ner": "O"
#       },
#       {
#         "id": 5,
#         "text": "jih",
#         "lemma": "on",
#         "upos": "PRON",
#         "xpos": "Pp3mpa--y",
#         "feats": "Case=Acc|Gender=Masc|Number=Plur|Person=3|PronType=Prs|Variant=Short",
#         "head": 7,
#         "deprel": "obj",
#         "ner": "O"
#       },
#       {
#         "id": 6,
#         "text": "večina",
#         "lemma": "večina",
#         "upos": "NOUN",
#         "xpos": "Ncfsn",
#         "feats": "Case=Nom|Gender=Fem|Number=Sing",
#         "head": 7,
#         "deprel": "nsubj",
#         "ner": "O"
#       },
#       {
#         "id": 7,
#         "text": "vodi",
#         "lemma": "voditi",
#         "upos": "VERB",
#         "xpos": "Vmpr3s",
#         "feats": "Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#         "head": 2,
#         "deprel": "conj",
#         "ner": "O"
#       },
#       {
#         "id": 8,
#         "text": "v",
#         "lemma": "v",
#         "upos": "ADP",
#         "xpos": "Sa",
#         "feats": "Case=Acc",
#         "head": 9,
#         "deprel": "case",
#         "ner": "O"
#       },
#       {
#         "id": 9,
#         "text": "Rusijo",
#         "lemma": "Rusija",
#         "upos": "PROPN",
#         "xpos": "Npfsa",
#         "feats": "Case=Acc|Gender=Fem|Number=Sing",
#         "head": 7,
#         "deprel": "obl",
#         "ner": "B-LOC"
#       },
#       {
#         "id": 10,
#         "text": "in",
#         "lemma": "in",
#         "upos": "CCONJ",
#         "xpos": "Cc",
#         "head": 11,
#         "deprel": "cc",
#         "ner": "O"
#       },
#       {
#         "id": 11,
#         "text": "Belorusijo",
#         "lemma": "Belorusija",
#         "upos": "PROPN",
#         "xpos": "Npfsa",
#         "feats": "Case=Acc|Gender=Fem|Number=Sing",
#         "head": 9,
#         "deprel": "conj",
#         "misc": "SpaceAfter=No",
#         "ner": "B-LOC"
#       },
#       {
#         "id": 12,
#         "text": ".",
#         "lemma": ".",
#         "upos": "PUNCT",
#         "xpos": "Z",
#         "head": 7,
#         "deprel": "punct",
#         "ner": "O"
#       }
#     ],
#     "# newpar id = 4\n# sent_id = 4.1\n# text = humanitarne koridorje, a jih večina vodi v Rusijo in Belorusijo.\n"
#   ],
#   [
#     [
#       {
#         "id": 1,
#         "text": "Tretji",
#         "lemma": "tretji",
#         "upos": "ADJ",
#         "xpos": "Mlomsn",
#         "feats": "Case=Nom|Gender=Masc|Number=Sing|NumType=Ord",
#         "head": 2,
#         "deprel": "amod",
#         "ner": "O"
#       },
#       {
#         "id": 2,
#         "text": "krog",
#         "lemma": "krog",
#         "upos": "NOUN",
#         "xpos": "Ncmsn",
#         "feats": "Case=Nom|Gender=Masc|Number=Sing",
#         "head": 5,
#         "deprel": "nsubj",
#         "ner": "O"
#       },
#       {
#         "id": 3,
#         "text": "mirovnih",
#         "lemma": "miroven",
#         "upos": "ADJ",
#         "xpos": "Agpnpg",
#         "feats": "Case=Gen|Degree=Pos|Gender=Neut|Number=Plur",
#         "head": 4,
#         "deprel": "amod",
#         "ner": "O"
#       },
#       {
#         "id": 4,
#         "text": "pogajanj",
#         "lemma": "pogajanje",
#         "upos": "NOUN",
#         "xpos": "Ncnpg",
#         "feats": "Case=Gen|Gender=Neut|Number=Plur",
#         "head": 2,
#         "deprel": "nmod",
#         "ner": "O"
#       },
#       {
#         "id": 5,
#         "text": "poteka",
#         "lemma": "potekati",
#         "upos": "VERB",
#         "xpos": "Vmpr3s",
#         "feats": "Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#         "head": 0,
#         "deprel": "root",
#         "ner": "O"
#       },
#       {
#         "id": 6,
#         "text": "v",
#         "lemma": "v",
#         "upos": "ADP",
#         "xpos": "Sl",
#         "feats": "Case=Loc",
#         "head": 8,
#         "deprel": "case",
#         "ner": "O"
#       },
#       {
#         "id": 7,
#         "text": "narodnem",
#         "lemma": "naroden",
#         "upos": "ADJ",
#         "xpos": "Agpmsl",
#         "feats": "Case=Loc|Degree=Pos|Gender=Masc|Number=Sing",
#         "head": 8,
#         "deprel": "amod",
#         "ner": "O"
#       },
#       {
#         "id": 8,
#         "text": "parku",
#         "lemma": "park",
#         "upos": "NOUN",
#         "xpos": "Ncmsl",
#         "feats": "Case=Loc|Gender=Masc|Number=Sing",
#         "head": 5,
#         "deprel": "obl",
#         "ner": "O"
#       },
#       {
#         "id": 9,
#         "text": "Beloveška",
#         "lemma": "Beloveška",
#         "upos": "PROPN",
#         "xpos": "Npfsn",
#         "feats": "Case=Nom|Gender=Fem|Number=Sing",
#         "head": 8,
#         "deprel": "nmod",
#         "ner": "B-LOC"
#       }
#     ],
#     "# newpar id = 5\n# sent_id = 5.1\n# text = Tretji krog mirovnih pogajanj poteka v narodnem parku Beloveška\n"
#   ],
#   [
#     [
#       {
#         "id": 1,
#         "text": "pušča",
#         "lemma": "puščati",
#         "upos": "VERB",
#         "xpos": "Vmpr3s",
#         "feats": "Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#         "head": 0,
#         "deprel": "root",
#         "misc": "SpaceAfter=No",
#         "ner": "O"
#       },
#       {
#         "id": 2,
#         "text": ",",
#         "lemma": ",",
#         "upos": "PUNCT",
#         "xpos": "Z",
#         "head": 5,
#         "deprel": "punct",
#         "ner": "O"
#       },
#       {
#         "id": 3,
#         "text": "ki",
#         "lemma": "ki",
#         "upos": "SCONJ",
#         "xpos": "Cs",
#         "head": 5,
#         "deprel": "mark",
#         "ner": "O"
#       },
#       {
#         "id": 4,
#         "text": "se",
#         "lemma": "se",
#         "upos": "PRON",
#         "xpos": "Px------y",
#         "feats": "PronType=Prs|Reflex=Yes|Variant=Short",
#         "head": 5,
#         "deprel": "expl",
#         "ner": "O"
#       },
#       {
#         "id": 5,
#         "text": "razteza",
#         "lemma": "raztezati",
#         "upos": "VERB",
#         "xpos": "Vmpr3s",
#         "feats": "Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#         "head": 1,
#         "deprel": "ccomp",
#         "ner": "O"
#       },
#       {
#         "id": 6,
#         "text": "med",
#         "lemma": "med",
#         "upos": "ADP",
#         "xpos": "Si",
#         "feats": "Case=Ins",
#         "head": 7,
#         "deprel": "case",
#         "ner": "O"
#       },
#       {
#         "id": 7,
#         "text": "Poljsko",
#         "lemma": "Poljska",
#         "upos": "PROPN",
#         "xpos": "Npfsi",
#         "feats": "Case=Ins|Gender=Fem|Number=Sing",
#         "head": 5,
#         "deprel": "obl",
#         "ner": "B-LOC"
#       },
#       {
#         "id": 8,
#         "text": "in",
#         "lemma": "in",
#         "upos": "CCONJ",
#         "xpos": "Cc",
#         "head": 9,
#         "deprel": "cc",
#         "ner": "O"
#       },
#       {
#         "id": 9,
#         "text": "Belorusijo",
#         "lemma": "Belorusija",
#         "upos": "PROPN",
#         "xpos": "Npfsi",
#         "feats": "Case=Ins|Gender=Fem|Number=Sing",
#         "head": 7,
#         "deprel": "conj",
#         "misc": "SpaceAfter=No",
#         "ner": "B-LOC"
#       },
#       {
#         "id": 10,
#         "text": ".",
#         "lemma": ".",
#         "upos": "PUNCT",
#         "xpos": "Z",
#         "head": 1,
#         "deprel": "punct",
#         "ner": "O"
#       }
#     ],
#     "# newpar id = 6\n# sent_id = 6.1\n# text = pušča, ki se razteza med Poljsko in Belorusijo.\n"
#   ],
#   [
#     [
#       {
#         "id": 1,
#         "text": "Ruske",
#         "lemma": "ruski",
#         "upos": "ADJ",
#         "xpos": "Agpmpa",
#         "feats": "Case=Acc|Degree=Pos|Gender=Masc|Number=Plur",
#         "head": 2,
#         "deprel": "amod",
#         "ner": "O"
#       },
#       {
#         "id": 2,
#         "text": "pogajalce",
#         "lemma": "pogajalec",
#         "upos": "NOUN",
#         "xpos": "Ncmpa",
#         "feats": "Case=Acc|Gender=Masc|Number=Plur",
#         "head": 0,
#         "deprel": "root",
#         "ner": "O"
#       }
#     ],
#     "# sent_id = 6.2\n# text = Ruske pogajalce\n"
#   ],
#   [
#     [
#       {
#         "id": 1,
#         "text": "vodi",
#         "lemma": "voditi",
#         "upos": "VERB",
#         "xpos": "Vmpr3s",
#         "feats": "Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#         "head": 0,
#         "deprel": "root",
#         "ner": "O"
#       },
#       {
#         "id": 2,
#         "text": "Vladimir",
#         "lemma": "Vladimir",
#         "upos": "PROPN",
#         "xpos": "Npmsn",
#         "feats": "Case=Nom|Gender=Masc|Number=Sing",
#         "head": 1,
#         "deprel": "nsubj",
#         "ner": "B-PER"
#       },
#       {
#         "id": 3,
#         "text": "Medinski",
#         "lemma": "Medinski",
#         "upos": "PROPN",
#         "xpos": "Npmsn",
#         "feats": "Case=Nom|Gender=Masc|Number=Sing",
#         "head": 2,
#         "deprel": "flat:name",
#         "misc": "SpaceAfter=No",
#         "ner": "I-PER"
#       },
#       {
#         "id": 4,
#         "text": ",",
#         "lemma": ",",
#         "upos": "PUNCT",
#         "xpos": "Z",
#         "head": 7,
#         "deprel": "punct",
#         "ner": "O"
#       },
#       {
#         "id": 5,
#         "text": "ki",
#         "lemma": "ki",
#         "upos": "SCONJ",
#         "xpos": "Cs",
#         "head": 7,
#         "deprel": "mark",
#         "ner": "O"
#       },
#       {
#         "id": 6,
#         "text": "je",
#         "lemma": "biti",
#         "upos": "AUX",
#         "xpos": "Va-r3s-n",
#         "feats": "Mood=Ind|Number=Sing|Person=3|Polarity=Pos|Tense=Pres|VerbForm=Fin",
#         "head": 7,
#         "deprel": "aux",
#         "ner": "O"
#       },
#       {
#         "id": 7,
#         "text": "dejal",
#         "lemma": "dejati",
#         "upos": "VERB",
#         "xpos": "Vmep-sm",
#         "feats": "Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part",
#         "head": 2,
#         "deprel": "acl",
#         "misc": "SpaceAfter=No",
#         "ner": "O"
#       },
#       {
#         "id": 8,
#         "text": ",",
#         "lemma": ",",
#         "upos": "PUNCT",
#         "xpos": "Z",
#         "head": 11,
#         "deprel": "punct",
#         "ner": "O"
#       },
#       {
#         "id": 9,
#         "text": "da",
#         "lemma": "da",
#         "upos": "SCONJ",
#         "xpos": "Cs",
#         "head": 11,
#         "deprel": "mark",
#         "ner": "O"
#       },
#       {
#         "id": 10,
#         "text": "je",
#         "lemma": "biti",
#         "upos": "AUX",
#         "xpos": "Va-r3s-n",
#         "feats": "Mood=Ind|Number=Sing|Person=3|Polarity=Pos|Tense=Pres|VerbForm=Fin",
#         "head": 11,
#         "deprel": "cop",
#         "ner": "O"
#       },
#       {
#         "id": 11,
#         "text": "Rusija",
#         "lemma": "Rusija",
#         "upos": "PROPN",
#         "xpos": "Npfsn",
#         "feats": "Case=Nom|Gender=Fem|Number=Sing",
#         "head": 7,
#         "deprel": "ccomp",
#         "ner": "B-LOC"
#       }
#     ],
#     "# newpar id = 7\n# sent_id = 7.1\n# text = vodi Vladimir Medinski, ki je dejal, da je Rusija\n"
#   ],
#   [
#     [
#       {
#         "id": 1,
#         "text": "\"",
#         "lemma": "\"",
#         "upos": "PUNCT",
#         "xpos": "Z",
#         "head": 3,
#         "deprel": "punct",
#         "misc": "SpaceAfter=No",
#         "ner": "O"
#       },
#       {
#         "id": 2,
#         "text": "nedvomno",
#         "lemma": "nedvomno",
#         "upos": "ADV",
#         "xpos": "Rgp",
#         "feats": "Degree=Pos",
#         "head": 3,
#         "deprel": "advmod",
#         "ner": "O"
#       },
#       {
#         "id": 3,
#         "text": "pripravljena",
#         "lemma": "pripravljen",
#         "upos": "ADJ",
#         "xpos": "Appfsn",
#         "feats": "Case=Nom|Degree=Pos|Gender=Fem|Number=Sing|VerbForm=Part",
#         "head": 0,
#         "deprel": "root",
#         "misc": "SpaceAfter=No",
#         "ner": "O"
#       },
#       {
#         "id": 4,
#         "text": "\"",
#         "lemma": "\"",
#         "upos": "PUNCT",
#         "xpos": "Z",
#         "head": 3,
#         "deprel": "punct",
#         "ner": "O"
#       },
#       {
#         "id": 5,
#         "text": "na",
#         "lemma": "na",
#         "upos": "ADP",
#         "xpos": "Sa",
#         "feats": "Case=Acc",
#         "head": 6,
#         "deprel": "case",
#         "ner": "O"
#       },
#       {
#         "id": 6,
#         "text": "pogovore",
#         "lemma": "pogovor",
#         "upos": "NOUN",
#         "xpos": "Ncmpa",
#         "feats": "Case=Acc|Gender=Masc|Number=Plur",
#         "head": 3,
#         "deprel": "obl",
#         "ner": "O"
#       },
#       {
#         "id": 7,
#         "text": "z",
#         "lemma": "z",
#         "upos": "ADP",
#         "xpos": "Si",
#         "feats": "Case=Ins",
#         "head": 9,
#         "deprel": "case",
#         "ner": "O"
#       },
#       {
#         "id": 8,
#         "text": "ukrajinsko",
#         "lemma": "ukrajinski",
#         "upos": "ADJ",
#         "xpos": "Agpfsi",
#         "feats": "Case=Ins|Degree=Pos|Gender=Fem|Number=Sing",
#         "head": 9,
#         "deprel": "amod",
#         "ner": "O"
#       },
#       {
#         "id": 9,
#         "text": "stranjo",
#         "lemma": "stran",
#         "upos": "NOUN",
#         "xpos": "Ncfsi",
#         "feats": "Case=Ins|Gender=Fem|Number=Sing",
#         "head": 6,
#         "deprel": "nmod",
#         "misc": "SpaceAfter=No",
#         "ner": "O"
#       },
#       {
#         "id": 10,
#         "text": ",",
#         "lemma": ",",
#         "upos": "PUNCT",
#         "xpos": "Z",
#         "head": 11,
#         "deprel": "punct",
#         "ner": "O"
#       },
#       {
#         "id": 11,
#         "text": "poroča",
#         "lemma": "poročati",
#         "upos": "VERB",
#         "xpos": "Vmpr3s",
#         "feats": "Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#         "head": 3,
#         "deprel": "parataxis",
#         "ner": "O"
#       }
#     ],
#     "# newpar id = 8\n# sent_id = 8.1\n# text = \"nedvomno pripravljena\" na pogovore z ukrajinsko stranjo, poroča\n"
#   ],
#   [
#     [
#       {
#         "id": 1,
#         "text": "ruska",
#         "lemma": "ruski",
#         "upos": "ADJ",
#         "xpos": "Agpfsn",
#         "feats": "Case=Nom|Degree=Pos|Gender=Fem|Number=Sing",
#         "head": 3,
#         "deprel": "amod",
#         "ner": "O"
#       },
#       {
#         "id": 2,
#         "text": "tiskovna",
#         "lemma": "tiskoven",
#         "upos": "ADJ",
#         "xpos": "Agpfsn",
#         "feats": "Case=Nom|Degree=Pos|Gender=Fem|Number=Sing",
#         "head": 3,
#         "deprel": "amod",
#         "ner": "O"
#       },
#       {
#         "id": 3,
#         "text": "agencija",
#         "lemma": "agencija",
#         "upos": "NOUN",
#         "xpos": "Ncfsn",
#         "feats": "Case=Nom|Gender=Fem|Number=Sing",
#         "head": 0,
#         "deprel": "root",
#         "ner": "O"
#       },
#       {
#         "id": 4,
#         "text": "TASS",
#         "lemma": "Tass",
#         "upos": "PROPN",
#         "xpos": "Npmsn",
#         "feats": "Case=Nom|Gender=Masc|Number=Sing",
#         "head": 3,
#         "deprel": "nmod",
#         "misc": "SpaceAfter=No",
#         "ner": "B-ORG"
#       },
#       {
#         "id": 5,
#         "text": ".",
#         "lemma": ".",
#         "upos": "PUNCT",
#         "xpos": "Z",
#         "head": 3,
#         "deprel": "punct",
#         "ner": "O"
#       }
#     ],
#     "# newpar id = 9\n# sent_id = 9.1\n# text = ruska tiskovna agencija TASS.\n"
#   ]
# ]

# %% [markdown]
# ## Rule-based systems
#
# Rule-based systems use manually defined set of rules to extract structured data. The extraction workflow generally consists of the following steps (*Rule-Based Information Extraction for Structured Data Acquisition using TEXTMARKER* (2008), Martin Atzmueller et al.):
#
# <img src="rule-based-system.png" />
#
# The use of statistical models or deep learning networks for structured data extraction is increasing, although commetcial systems still heavily rely on manual extraction rules. Pleae read the IBM paper *Rule-based Information Extraction is Dead! Long Live Rule-based Information Extraction Systems!* (2013) by Laura Chiticariu et al..
#
# ### GATE
#
# [GATE](https://gate.ac.uk/) is a natural language processing framework that consists of a GUI application, a set of extensible tools and a Java library to develop custom extensions.
#
# It includes a rule-based information extraction system called [ANNIE](https://gate.ac.uk/sale/tao/splitch6.html#x9-1200006) that heavily relies on [JAPE](https://gate.ac.uk/sale/tao/splitch8.html#x12-2070008) (Java Annotations Patterns Engine) rules.
#
# <img src="gate-developer.png" />
#
# ## Other platforms
#
# ### UIMA
#
# [Apache UIMA](https://uima.apache.org) is another framework for information extraction. Apart from open-source plugins, some commercialized versions exist. The framework became especially known after the IBM Watson's win at the [Jeopardy challenge](https://www.youtube.com/watch?v=WFR3lOm_xhE) because Watson engine was based on UIMA.
#
# ### KNIME Analytics Platform
#
# [KNIME](https://www.knime.com/) is an open-source tool that enables data analysis and visualizations without programming. The low/no-code user interface is intended for beginners and advanced users that can use an enormous amount of predeveloped plugins. The company that develops and supports the tool offers also premium features such as cloud collaboration, private space, custom plugins development, integration with other systems, ...
#
# <img src="knime.png" />
#
# Also check a review of tools for NLP democratization: [Zasnova splošnega ogrodja in podatkovnega modela za obdelavo naravnega jezika – ANGLEr
# (2023)](https://ebooks.uni-lj.si/ZalozbaUL/catalog/view/522/852/9449) by Slavko Žitnik.

# %% [markdown]
# # Regular expressions
#
# One of the standardized ways to extract structured information from text is the use of regular expressions. To get familiar with the regular expressions, follow a tutorial at [RegexOne](https://regexone.com/) or go through explanations at [Regular-Expressions.info](http://www.regular-expressions.info/).
#
# While you learn and also when you want to test some regular expression examples against some text, you can help yourself using tools such as [Regex101](https://regex101.com/).
#
# ### Regular expressions in Python
# Let's try some regular expressions in Python.

# %%
text = """Mr. Swensen, 62, runs the school’s $25.4 billion endowment, one of the largest in the country. 
Since November 1 2016 he is joined by his intellectual sparring partner, Mr. Dean Takahashi, his senior director."""

# %%
import re

regex = "Mr. (\w+)"

# Find person
personPattern = re.compile(regex)
match = personPattern.search(text)
print("Found person: '{}'.".format( match.group(1) ))
# Out:
# Found person: 'Swensen'.

# %%
# Find all persons
matches = re.finditer(regex, text)
for match in matches:
    print("Found person: '{}'.".format( match.group(1) ))
# Out:
# Found person: 'Swensen'.
# Found person: 'Dean'.

# %%
# Find money amounts
regex = "[$€]\s*[0-9\.,]+"
matches = re.finditer(regex, text)
for match in matches:
    print("Amount: '{}'.".format( match.group(0) ))
# Out:
# Amount: '$25.4'.

# %%
# TODO: write a general regex for dates while identifying month, day and year separately

# %% [markdown]
# ### Exercise
#
# #### GATE and JAPE rules
#
# Install GATE Developer, try to use ANNIE against some english news text, investigate JAPE rules (some predefined ones are listed [here](https://gate.ac.uk/sale/tao/splitap6.html#x38-773000F)). Try to define some new JAPE rules.
#
# #### NLTK regular expressions
#
# To check some simple examples using Python and NLTK, please read *Regular Expressions for Natural Language Processing* (2006) by Steven Bird and Ewan Klein. Solve the exercises at the end of the document.
#
# #### NLP platforms
#
# Check the platforms review (see above), install and try to use a platform of your choice. Solve the problem below using the selected platform.
#
# #### CMU Seminars
#
# 1. Download the [CMU Seminar Announcements](https://people.cs.umass.edu/~mccallum/data/sa-tagged.tar.gz) dataset.
# 2. Remove all XML tags from texts.
# 3. Use regular expressions to recognize parts of the announcements. Which parts can you recognize (date, time, location, names, emails)?
